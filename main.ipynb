# %% [markdown]
# ### Load Necessay libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Basic Graph

# %%
x =[1,2,3]
y = [2,4,6]
plt.plot(x, y)
plt.title("My First Graph", fontdict={"fontname": "Italic"})
plt.xlabel("This is x label")
plt.ylabel("this is y label")
# Out:
# Text(0, 0.5, 'this is y label')
# findfont: Font family 'Italic' not found.
# findfont: Font family 'Italic' not found.
# findfont: Font family 'Italic' not found.
# findfont: Font family 'Italic' not found.
# findfont: Font family 'Italic' not found.
# findfont: Font family 'Italic' not found.
